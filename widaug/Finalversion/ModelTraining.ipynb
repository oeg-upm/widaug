# %% [markdown]
# #Installation

# %%
# !pip install datasets
# !pip install transformers
# !pip install seqeval

# %%
import os
import itertools
import pandas as pd
import numpy as np
from datasets import Dataset
from datasets import load_metric
from transformers import AutoTokenizer
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer
from transformers import DataCollatorForTokenClassification
import torch

# %% [markdown]
# #Functions

# %%
def read_dataset(dir):
  res = pd.read_csv(dir)

  res = res.apply(lambda x : x.str[2:-2])
  res = res.apply(lambda x: x.str.split("\', \'"))
  return res

# %% [markdown]
# #Dataset Reading
#
# Read all datasets
#
# </br>

# %% [markdown]
# **VALIDATION**
#
# ProfNER original training dataset

# %%
df_valid = read_dataset('valid.csv')
df_valid
# Out:
#                                                  tokens  \
# 0                        [COMUNICADO, POR, CORONAVIRUS]
# 1     [El, Presidente, Ruso, Vladimir, Putin, ha, di...
# 2                                  [#, nomequedoencasa]
# 3     [“, La, falta, de, transparencia, en, asuntos,...
# 4     [Esto, nos, demuestra, que, los, regímenes, au...
# ...                                                 ...
# 4248                 [89, tacos, y, virus, superado, .]
# 4249                                                [😍]
# 4250               [Sigan, para, bingo, en, este, 2020]
# 4251  [🇪, 🇸, |, URGENTE, -, CORONAVIRUS, :, España, ...
# 4252  [La, mascarilla, ,, en, días, de, calor, ,, pu...
#
#                                                ner_tags
# 0                                             [O, O, O]
# 1     [O, B-PROFESION, O, O, O, O, O, O, O, O, O, O,...
# 2                                                [O, O]
# 3     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# ...                                                 ...
# 4248                                 [O, O, O, O, O, O]
# 4249                                                [O]
# 4250                                 [O, O, O, O, O, O]
# 4251  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4252  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
# [4253 rows x 2 columns]

# %% [markdown]
# **BASE**
#
# ProfNER original training dataset

# %%
df_base = read_dataset('base.csv')
df_base
# Out:
#                                                   tokens  \
# 0      [Cerramos, nuestra, querida, Radio, 😢, Nuestro...
# 1      [Desde, mañana, todos, los, programas, de, Rad...
# 2      [Seguimos, al, aire, con, el, compromiso, de, ...
# 3      [#, OtroEscandalo, #, HastaCuando, #, Denuncia...
# 4      [¿, Es, necesario, entregar, nuestra, privacid...
# ...                                                  ...
# 12702                     [Se, os, ve, el, plumero, ...]
# 12703                                     [¡A, TOD@S, !]
# 12704  [Corríjanme, si, me, equivoco, ,, pero, somos,...
# 12705  [Viendo, que, tenemos, 7, veces, más, casos, q...
# 12706  [Así, ha, colaborado, el, hombre, sin, saberlo...
#
#                                                 ner_tags
# 0      [O, O, O, O, O, O, B-PROFESION, O, B-PROFESION...
# 1          [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 2      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4             [O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# ...                                                  ...
# 12702                                 [O, O, O, O, O, O]
# 12703                                          [O, O, O]
# 12704  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 12705  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 12706  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
# [12707 rows x 2 columns]

# %% [markdown]
# **FILTER**
#
# ProfNER training dataset filtered with only 50% of entities

# %%
df_filter = read_dataset('filter.csv')
df_filter
# Out:
#                                                   tokens  \
# 0      [Desde, mañana, todos, los, programas, de, Rad...
# 1      [Seguimos, al, aire, con, el, compromiso, de, ...
# 2      [#, OtroEscandalo, #, HastaCuando, #, Denuncia...
# 3      [¿, Es, necesario, entregar, nuestra, privacid...
# 4      [La, privacidad, en, tiempos, de, coronavirus,...
# ...                                                  ...
# 11951                     [Se, os, ve, el, plumero, ...]
# 11952                                     [¡A, TOD@S, !]
# 11953  [Corríjanme, si, me, equivoco, ,, pero, somos,...
# 11954  [Viendo, que, tenemos, 7, veces, más, casos, q...
# 11955  [Así, ha, colaborado, el, hombre, sin, saberlo...
#
#                                                 ner_tags
# 0          [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 1      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3             [O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 4                   [O, O, O, O, O, O, O, O, O, O, O, O]
# ...                                                  ...
# 11951                                 [O, O, O, O, O, O]
# 11952                                          [O, O, O]
# 11953  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 11954  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 11955  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
# [11956 rows x 2 columns]

# %% [markdown]
# **WIKIPEDIA**
#
# ProfNER filtered set with sentences generated with wikipedia

# %%
df_wikipedia = read_dataset('dataaug_wikipedia.csv')
df_wikipedia
# Out:
#                                                   tokens  \
# 0      [Desde, mañana, todos, los, programas, de, Rad...
# 1      [Seguimos, al, aire, con, el, compromiso, de, ...
# 2      [#, OtroEscandalo, #, HastaCuando, #, Denuncia...
# 3      [¿, Es, necesario, entregar, nuestra, privacid...
# 4      [La, privacidad, en, tiempos, de, coronavirus,...
# ...                                                  ...
# 12702  [Los, crupiers, suelen, ser, empleados, por, l...
# 12703  [El, crupier, en, cada, juego, se, atendrá, ex...
# 12704  [Los, métodos, de, entrenamiento, para, conver...
# 12705  [En, Estados, Unidos, de, América, ,, el, blac...
# 12706  [En, Europa, ,, los, crupiers, suelen, a, apre...
#
#                                                 ner_tags
# 0          [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 1      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3             [O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 4                   [O, O, O, O, O, O, O, O, O, O, O, O]
# ...                                                  ...
# 12702              [O, B-PROFESION, O, O, O, O, O, O, O]
# 12703  [O, B-PROFESION, O, O, O, O, O, O, O, O, O, O,...
# 12704  [O, O, O, O, O, O, O, O, B-PROFESION, O, O, O,...
# 12705  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 12706     [O, O, O, O, B-PROFESION, O, O, O, O, O, O, O]
#
# [12707 rows x 2 columns]

# %% [markdown]
# **WORD EMBEDDING**
#
# ProfNER filtered set with sentences generated with wikipedia (using word_embedding similarity for semantic relevance)

# %%
df_embedding = read_dataset('dataaug_wikipedia+embedding.csv')
df_embedding
# Out:
#                                                   tokens  \
# 0      [Desde, mañana, todos, los, programas, de, Rad...
# 1      [Seguimos, al, aire, con, el, compromiso, de, ...
# 2      [#, OtroEscandalo, #, HastaCuando, #, Denuncia...
# 3      [¿, Es, necesario, entregar, nuestra, privacid...
# 4      [La, privacidad, en, tiempos, de, coronavirus,...
# ...                                                  ...
# 12702  [No, todos, los, operadores, lineales, interes...
# 12703  [Si, un, operador, está, definido, entre, dos,...
# 12704  [Su, nombre, depende, del, autor, ,, son, los,...
# 12705  [Los, operadores, de, orden, establecen, o, ve...
# 12706  [Los, operadores, lógicos, nos, proporcionan, ...
#
#                                                 ner_tags
# 0          [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 1      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3             [O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 4                   [O, O, O, O, O, O, O, O, O, O, O, O]
# ...                                                  ...
# 12702  [O, O, O, B-PROFESION, O, O, O, O, O, O, O, O,...
# 12703  [O, O, B-PROFESION, O, O, O, O, O, O, O, O, O,...
# 12704  [O, O, O, O, O, O, O, O, B-PROFESION, O, O, O,...
# 12705  [O, B-PROFESION, O, O, O, O, O, O, O, O, O, O,...
# 12706  [O, B-PROFESION, O, O, O, O, O, O, O, O, O, O,...
#
# [12707 rows x 2 columns]

# %% [markdown]
# #Model Settings

# %%
label_list = ['O', 'B-PROFESION', 'I-PROFESION', 'B-SITUACION_LABORAL', 'I-SITUACION_LABORAL', 'B-ACTIVIDAD', 'I-ACTIVIDAD', 'B-FIGURATIVA', 'I-FIGURATIVA']
label_encoding_dict = {'O': 0, 'B-PROFESION': 1, 'I-PROFESION': 2, 'B-SITUACION_LABORAL':3, 'I-SITUACION_LABORAL':4, 'B-ACTIVIDAD':5, 'I-ACTIVIDAD':6, 'B-FIGURATIVA':7, 'I-FIGURATIVA':8}

task = "ner" 

model_checkpoint = "CenIA/distillbert-base-spanish-uncased"

batch_size = 16

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, add_prefix_space=True, truncation=True, padding=True, max_length=512)

# %%
def tokenize_and_align_labels(examples):
    label_all_tokens = True
    tokenized_inputs = tokenizer(list(examples["tokens"]), padding='max_length', truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"{task}_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif label[word_idx] == '0':
                label_ids.append(0)
            elif word_idx != previous_word_idx:
                label_ids.append(label_encoding_dict[label[word_idx]])
            else:
                label_ids.append(label_encoding_dict[label[word_idx]] if label_all_tokens else -100)
            previous_word_idx = word_idx
        labels.append(label_ids)
        
    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %% [markdown]
# #Training

# %% [markdown]
# ###Base

# %%
train_dataset = Dataset.from_pandas(df_base)
test_dataset = Dataset.from_pandas(df_valid)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
test_tokenized_datasets = test_dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/13 [00:00<?, ?ba/s]
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return {"precision": results["overall_precision"], "recall": results["overall_recall"], "f1": results["overall_f1"], "accuracy": results["overall_accuracy"]}
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=test_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
trainer.evaluate()
trainer.save_model('base.model')
# Out:
# Downloading:   0%|          | 0.00/530 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/257M [00:00<?, ?B/s]
# Some weights of the model checkpoint at CenIA/distillbert-base-spanish-uncased were not used when initializing DistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at CenIA/distillbert-base-spanish-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# The following columns in the training set don't have a corresponding argument in `DistilBertForTokenClassification.forward` and have been ignored: ner_tags, tokens. If ner_tags, tokens are not expected by `DistilBertForTokenClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 12707
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2385
#     <div>
#
#       <progress value='4' max='2385' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   4/2385 01:51 < 36:53:26, 0.02 it/s, Epoch 0.00/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-2a768c797664> in <module>()
#      35 )
#      36
# ---> 37 trainer.train()
#      38 trainer.evaluate()
#      39 trainer.save_model('base.model')
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1319             resume_from_checkpoint=resume_from_checkpoint,
#    1320             trial=trial,
# -> 1321             ignore_keys_for_eval=ignore_keys_for_eval,
#    1322         )
#    1323
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1552                         tr_loss_step = self.training_step(model, inputs)
#    1553                 else:
# -> 1554                     tr_loss_step = self.training_step(model, inputs)
#    1555
#    1556                 if (
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2199             loss = self.deepspeed.backward(loss)
#    2200         else:
# -> 2201             loss.backward()
#    2202
#    2203         return loss.detach()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %% [markdown]
# ###Filter

# %%
train_dataset = Dataset.from_pandas(df_filter)
test_dataset = Dataset.from_pandas(df_valid)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
test_tokenized_datasets = test_dataset.map(tokenize_and_align_labels, batched=True)

# %%
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return {"precision": results["overall_precision"], "recall": results["overall_recall"], "f1": results["overall_f1"], "accuracy": results["overall_accuracy"]}
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=test_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
trainer.evaluate()
trainer.save_model('filter.model')

# %% [markdown]
# ###Wikipedia

# %%
train_dataset = Dataset.from_pandas(df_wikipedia)
test_dataset = Dataset.from_pandas(df_valid)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
test_tokenized_datasets = test_dataset.map(tokenize_and_align_labels, batched=True)

# %%
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return {"precision": results["overall_precision"], "recall": results["overall_recall"], "f1": results["overall_f1"], "accuracy": results["overall_accuracy"]}
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=test_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
trainer.evaluate()
trainer.save_model('wikipedia.model')

# %% [markdown]
# ###Embedding

# %%
train_dataset = Dataset.from_pandas(df_embedding)
test_dataset = Dataset.from_pandas(df_valid)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
test_tokenized_datasets = test_dataset.map(tokenize_and_align_labels, batched=True)

# %%
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return {"precision": results["overall_precision"], "recall": results["overall_recall"], "f1": results["overall_f1"], "accuracy": results["overall_accuracy"]}
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=test_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
trainer.evaluate()
trainer.save_model('embedding.model')

# %% [markdown]
# #Saving

# %%
# !pip install pyocclient
import owncloud
oc = owncloud.Client('https://delicias.dia.fi.upm.es/nextcloud/')
oc.login('asanchez', 'AS.sczz.448')

# %%
# !zip -r ./base.model.zip ./base.model
# !zip -r ./filter.model.zip ./filter.model
# !zip -r ./wikipedia.model.zip ./wikipedia.model
# !zip -r ./embedding.model.zip ./embedding.model

# %%
oc.put_file('profner/new-filter/base-model.zip', 'base.model.zip')
oc.put_file('profner/new-filter/filter-model.zip', 'filter.model.zip')
oc.put_file('profner/new-filter/wikipedia-model.zip', 'wikipedia.model.zip')
oc.put_file('profner/new-filter/embedding-model.zip', 'embedding.model.zip')
